# %% [markdown]
# <a href="https://colab.research.google.com/github/jacobpad/DS-Unit-3-Sprint-1-Software-Engineering/blob/master/u3_s1_m1_testing_packages.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -i https://test.pypi.org/simple/ lambdata-jacobpad-unit-3==0.0.1
# Out:
# Looking in indexes: https://test.pypi.org/simple/
# ...

# %%
from my_lambdata.my_mod import ten_x

# %%
ten_x(3)
# Out:
# 30

# %%
dir(ten_x)
# Out:
# ['__annotations__',
#  '__call__',
#  '__class__',
#  '__closure__',
#  '__code__',
#  '__defaults__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__get__',
#  '__getattribute__',
#  '__globals__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__kwdefaults__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__name__',
#  '__ne__',
#  '__new__',
#  '__qualname__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__']
